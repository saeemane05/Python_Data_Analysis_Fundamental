# %% [markdown]
# ## SECTION 1 — BASICS

# %% [markdown]
# Create a 1D NumPy array with values from 10 to 50 (step = 5)

# %% [markdown]
# Find the shape and dtype of an array

# %% [markdown]
# Convert a Python list of strings into a NumPy array

# %% [markdown]
# Create a 3×3 matrix filled with zeros

# %% [markdown]
# Create a 4×4 identity matrix

# %% [markdown]
# Generate 5 evenly spaced values between 0 and 1

# %% [markdown]
# Reshape a 1D array of 12 elements into a 3×4 matrix

# %% [markdown]
# Flatten a 2D array back into 1D

# %% [markdown]
# Check if two arrays have the same shape

# %% [markdown]
# Copy an array without affecting the original

# %% [markdown]
# ## SECTION 2 — INDEXING & SLICING

# %% [markdown]
# Extract the 2nd row from a 5×5 matrix

# %% [markdown]
# Extract the last column from a matrix

# %% [markdown]
# Extract a 2×2 submatrix from the center

# %% [markdown]
# Reverse a 1D NumPy array

# %% [markdown]
# Replace all values > 10 with 10

# %% [markdown]
# Get all even numbers from an array

# %% [markdown]
# Count how many values are > mean

# %% [markdown]
# Set diagonal elements to 0

# %% [markdown]
# Find the index of the max element

# %% [markdown]
# Sort an array but keep original unchanged

# %% [markdown]
# ## SECTION 3 — BROADCASTING & MATH

# %% [markdown]
# ## SECTION 4 — RANDOM & STATS

# %% [markdown]
# ## SECTION 5 — LINEAR ALGEBRA
