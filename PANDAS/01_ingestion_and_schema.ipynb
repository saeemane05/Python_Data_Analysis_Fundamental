# %% [markdown]
# # Introduction to Pandas
#
# ## What is Pandas?
# **Pandas** is an open-source Python library used for **data manipulation and data analysis**.
# It provides fast, flexible, and easy-to-use data structures for working with **structured data** such as tables, time series, and CSV/Excel files.
#
# The two main data structures in Pandas are:
# - **Series** → 1D labeled array (like a column in a table)
# - **DataFrame** → 2D labeled table (like a spreadsheet or SQL table)
#
# Pandas is widely used in:
# - Data Science
# - Machine Learning
# - Data Engineering
# - Finance
# - Scientific Computing
#
# ---
#
# ## Who Invented Pandas?
#
# Pandas was **created by Wes McKinney in 2008** while he was working at **AQR Capital Management**, a quantitative finance firm.
#
# ### Why It Was Created
# Wes McKinney needed a powerful tool to:
# - Clean messy financial data
# - Handle missing values
# - Work with time-series data efficiently
# - Perform fast statistical analysis
#
# Python didn’t have a strong data analysis library at the time — so he built Pandas.
#
# ---
#
# ## Meaning of the Name "Pandas"
#
# The name **Pandas** comes from:
# > **“Panel Data”** — a term used in econometrics for multi-dimensional structured datasets.
#
# ---
#
# ## Why Pandas is Important Today
#
# Pandas is now a **core tool in the Python data ecosystem** and works closely with:
# - **NumPy** (numerical computing)
# - **Matplotlib / Seaborn** (visualization)
# - **Scikit-learn** (machine learning)
#
# It powers workflows from **simple CSV cleaning** to **large-scale data pipelines**.

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Series in Pandas

# %%
a = pd.Series([1 , 2, 3, 4, 5])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a.dtypes
# Out:
# dtype('int64')

# %%
a.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
a.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# ## Assigning a name to the series

# %%
a.name = "Numbers"
print(a.name)
# Out:
# Numbers

# %% [markdown]
# ## Indexing

# %%
a[0]
# Out:
# np.int64(1)

# %%
a[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# Name: Numbers, dtype: int64

# %% [markdown]
# ## Location Based Indexing by `iloc()`

# %%
a.iloc[3]
# Out:
# np.int64(4)

# %%
a.iloc[[1 ,2 ,4]] # works only for integers
# Out:
# 1    2
# 2    3
# 4    5
# Name: Numbers, dtype: int64

# %%
a.name = 'calories'

# %% [markdown]
# # Assign index

# %%
Index = ['apple' , 'mango' , 'banana','grapes', 'Peach']
a.index = Index
a
# Out:
# apple     1
# mango     2
# banana    3
# grapes    4
# Peach     5
# Name: calories, dtype: int64

# %%
a['grapes']
# Out:
# np.int64(4)

# %% [markdown]
# # Difference between iloc and loc functions

# %%
a.iloc[4] # can index only th integers
# Out:
# np.int64(5)

# %%
a.loc['grapes'] # can also index the strings
# Out:
# np.int64(4)

# %% [markdown]
# #` In label based indexing , both the starting and the ending values are inlcuded`

# %%
a['banana': 'Peach']
# Out:
# banana    3
# grapes    4
# Peach     5
# Name: calories, dtype: int64

# %%
a.loc['banana':'grapes']
# Out:
# banana    3
# grapes    4
# Name: calories, dtype: int64

# %%
fruit_protein = {
    "Fruit": ["Apple", "Banana", "Orange", "Mango", "Papaya", "Guava", "Strawberry"],
    "Protein (g per 100g)": [0.3, 1.1, 0.9, 0.8, 0.5, 2.6, 0.7]
}

# %%
s2 = pd.Series(fruit_protein["Protein (g per 100g)"], index = fruit_protein["Fruit"])
s2
# Out:
# Apple         0.3
# Banana        1.1
# Orange        0.9
# Mango         0.8
# Papaya        0.5
# Guava         2.6
# Strawberry    0.7
# dtype: float64

# %%
print(s2.iloc[5])
# Out:
# 2.6

# %%
print(s2.loc['Apple': 'Papaya'])
# Out:
# Apple     0.3
# Banana    1.1
# Orange    0.9
# Mango     0.8
# Papaya    0.5
# dtype: float64

# %%
print(s2[::-1])
# Out:
# Strawberry    0.7
# Guava         2.6
# Papaya        0.5
# Mango         0.8
# Orange        0.9
# Banana        1.1
# Apple         0.3
# dtype: float64

# %% [markdown]
# # Conditional Selections

# %%
print(s2>1)
# Out:
# Apple         False
# Banana         True
# Orange        False
# Mango         False
# Papaya        False
# Guava          True
# Strawberry    False
# dtype: bool

# %%
s2[s2>1] #If u want to diplay all the True
# Out:
# Banana    1.1
# Guava     2.6
# dtype: float64

# %% [markdown]
# # Logical Operators

# %%
s2[(s2>1) & (s2<= 3)]
# Out:
# Banana    1.1
# Guava     2.6
# dtype: float64

# %% [markdown]
# # Not operation

# %%
s2[~(s2>1)]  # ~  - For balues not greater than 1
# Out:
# Apple         0.3
# Orange        0.9
# Mango         0.8
# Papaya        0.5
# Strawberry    0.7
# dtype: float64

# %%
s2['Banana'] = 2.8

# %%
s2
# Out:
# Apple         0.3
# Banana        2.8
# Orange        0.9
# Mango         0.8
# Papaya        0.5
# Guava         2.6
# Strawberry    0.7
# dtype: float64

# %%
data = {
    "Name":['saee' , 'kishori' , 'Charlie' , 'David' , 'Shravani'] ,
    "Age" : [21 , 20 , 25 , 26 , 23],
    "Department":['HR' , 'IT' , 'Finance' , 'Medical' , 'HR'],
    "Salary":[10000000000 , 5000000 , 300000 , 100000 , 450000]
}

# %%
data
# Out:
# {'Name': ['saee', 'kishori', 'Charlie', 'David', 'Shravani'],
#  'Age': [21, 20, 25, 26, 23],
#  'Department': ['HR', 'IT', 'Finance', 'Medical', 'HR'],
#  'Salary': [10000000000, 5000000, 300000, 100000, 450000]}

# %% [markdown]
# ## Creating a DataFrame

# %%
df = pd.DataFrame(data)
df
# Out:
#        Name  Age Department       Salary
# 0      saee   21         HR  10000000000
# 1   kishori   20         IT      5000000
# 2   Charlie   25    Finance       300000
# 3     David   26    Medical       100000
# 4  Shravani   23         HR       450000

# %%
df.head() # First few rows
# Out:
#        Name  Age Department       Salary
# 0      saee   21         HR  10000000000
# 1   kishori   20         IT      5000000
# 2   Charlie   25    Finance       300000
# 3     David   26    Medical       100000
# 4  Shravani   23         HR       450000

# %%
df.tail() # Last few Rows
# Out:
#        Name  Age Department       Salary
# 0      saee   21         HR  10000000000
# 1   kishori   20         IT      5000000
# 2   Charlie   25    Finance       300000
# 3     David   26    Medical       100000
# 4  Shravani   23         HR       450000

# %%
df.iloc[1:4]
# Out:
#       Name  Age Department   Salary
# 1  kishori   20         IT  5000000
# 2  Charlie   25    Finance   300000
# 3    David   26    Medical   100000

# %%
df.loc[1:3 , ['Age' , 'Department']]
# Out:
#    Age Department
# 1   20         IT
# 2   25    Finance
# 3   26    Medical

# %%
df.loc[: , ['Salary' , 'Name' , 'Age']]
# Out:
#         Salary      Name  Age
# 0  10000000000      saee   21
# 1      5000000   kishori   20
# 2       300000   Charlie   25
# 3       100000     David   26
# 4       450000  Shravani   23

# %%
df.loc[::-1 , ['Salary' , 'Name' , 'Age']]
# Out:
#         Salary      Name  Age
# 4       450000  Shravani   23
# 3       100000     David   26
# 2       300000   Charlie   25
# 1      5000000   kishori   20
# 0  10000000000      saee   21

# %%
df[['Age' , 'Department']]
# Out:
#    Age Department
# 0   21         HR
# 1   20         IT
# 2   25    Finance
# 3   26    Medical
# 4   23         HR

# %%
df.sample(5 , random_state = 42) #random_state is just a seed number for the random generator.
# Out:
#        Name  Age Department       Salary
# 1   kishori   20         IT      5000000
# 4  Shravani   23         HR       450000
# 2   Charlie   25    Finance       300000
# 0      saee   21         HR  10000000000
# 3     David   26    Medical       100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Department  5 non-null      object
#  3   Salary      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#             Age        Salary
# count   5.00000  5.000000e+00
# mean   23.00000  2.001170e+09
# std     2.54951  4.471482e+09
# min    20.00000  1.000000e+05
# 25%    21.00000  3.000000e+05
# 50%    23.00000  4.500000e+05
# 75%    25.00000  5.000000e+06
# max    26.00000  1.000000e+10

# %%
df.describe(include = 'all')
# Out:
#         Name       Age Department        Salary
# count      5   5.00000          5  5.000000e+00
# unique     5       NaN          4           NaN
# top     saee       NaN         HR           NaN
# freq       1       NaN          2           NaN
# mean     NaN  23.00000        NaN  2.001170e+09
# std      NaN   2.54951        NaN  4.471482e+09
# min      NaN  20.00000        NaN  1.000000e+05
# 25%      NaN  21.00000        NaN  3.000000e+05
# 50%      NaN  23.00000        NaN  4.500000e+05
# 75%      NaN  25.00000        NaN  5.000000e+06
# max      NaN  26.00000        NaN  1.000000e+10

# %%
df['Age'].value_counts() #It counts how many times each unique value appears in the "Age" column.
# Out:
# Age
# 21    1
# 20    1
# 25    1
# 26    1
# 23    1
# Name: count, dtype: int64

# %% [markdown]
# ## Typecasting

# %%
df['age'] = df['Age'].astype(int)

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['Age'] = df['Age'].astype(float)

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %%
df['Age'] = df['Age'].astype(str)

# %%
df['Age'].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#        Name   Age Department       Salary  age
# 0      saee  21.0         HR  10000000000   21
# 1   kishori  20.0         IT      5000000   20
# 2   Charlie  25.0    Finance       300000   25
# 3     David  26.0    Medical       100000   26
# 4  Shravani  23.0         HR       450000   23

# %%
df.dtypes
# Out:
# Name          object
# Age           object
# Department    object
# Salary         int64
# age            int64
# dtype: object

# %%
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')
df['Salary'] = df['Salary'] + 5000

# %%
df['Salary'] = pd.to_datetime(df['Salary'])
df['Salary']
# Out:
# age
# (21.0, 21)   1970-01-01 00:00:10.000005
# (20.0, 20)   1970-01-01 00:00:00.005005
# (25.0, 25)   1970-01-01 00:00:00.000305
# (26.0, 26)   1970-01-01 00:00:00.000105
# (23.0, 23)   1970-01-01 00:00:00.000455
# Name: Salary, dtype: datetime64[ns]

# %%
df.isna()
# Out:
#     Name    Age  Department  Salary    age
# 0  False  False       False   False  False
# 1  False  False       False   False  False
# 2  False  False       False   False  False
# 3  False  False       False   False  False
# 4  False  False       False   False  False

# %%
df.isna().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# age           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# # Adding a real time Timestamp

# %%
df['Timestamp'] = pd.Timestamp.now()
df
# Out:
#        Name   Age Department                     Salary  age  \
# 0      saee  21.0         HR 1970-01-01 00:00:10.000000   21
# 1   kishori  20.0         IT 1970-01-01 00:00:00.005000   20
# 2   Charlie  25.0    Finance 1970-01-01 00:00:00.000300   25
# 3     David  26.0    Medical 1970-01-01 00:00:00.000100   26
# 4  Shravani  23.0         HR 1970-01-01 00:00:00.000450   23
#
#                    Timestamp
# 0 2026-01-25 17:51:55.740111
# 1 2026-01-25 17:51:55.740111
# 2 2026-01-25 17:51:55.740111
# 3 2026-01-25 17:51:55.740111
# 4 2026-01-25 17:51:55.740111

# %% [markdown]
# ## `df.duplicated()`
#
# This returns a Boolean Series:
#
# True → this row is a duplicate
#
# False → this row is unique

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # `nunique()` - To chcek the number of unique values in the dataframe

# %%
df.nunique()
# Out:
# Name          5
# Age           5
# Department    4
# Salary        5
# age           5
# Timestamp     1
# dtype: int64

# %%
df.nunique().sum()
# Out:
# np.int64(25)

# %% [markdown]
# # `df.rename(columns = {initial : change} , inplace  =  True) - Used for renaming the column of the dataframe
# # `inplace  = True` - It modifies the original DataFrame directly instead of returning a new one.

# %%
df.rename(columns = {'Age': 'age'} , inplace = True)

# %%
df
# Out:
#        Name   age Department                     Salary  age  \
# 0      saee  21.0         HR 1970-01-01 00:00:10.000000   21
# 1   kishori  20.0         IT 1970-01-01 00:00:00.005000   20
# 2   Charlie  25.0    Finance 1970-01-01 00:00:00.000300   25
# 3     David  26.0    Medical 1970-01-01 00:00:00.000100   26
# 4  Shravani  23.0         HR 1970-01-01 00:00:00.000450   23
#
#                    Timestamp
# 0 2026-01-25 17:51:55.740111
# 1 2026-01-25 17:51:55.740111
# 2 2026-01-25 17:51:55.740111
# 3 2026-01-25 17:51:55.740111
# 4 2026-01-25 17:51:55.740111

# %% [markdown]
# # `set_index()` - used to set a particular column as index of that dataframe

# %%
df.set_index('age' , inplace  =  True)

# %%
df
# Out:
#                 Name Department                     Salary  \
# age
# (21.0, 21)      saee         HR 1970-01-01 00:00:10.000000
# (20.0, 20)   kishori         IT 1970-01-01 00:00:00.005000
# (25.0, 25)   Charlie    Finance 1970-01-01 00:00:00.000300
# (26.0, 26)     David    Medical 1970-01-01 00:00:00.000100
# (23.0, 23)  Shravani         HR 1970-01-01 00:00:00.000450
#
#                             Timestamp
# age
# (21.0, 21) 2026-01-25 17:51:55.740111
# (20.0, 20) 2026-01-25 17:51:55.740111
# (25.0, 25) 2026-01-25 17:51:55.740111
# (26.0, 26) 2026-01-25 17:51:55.740111
# (23.0, 23) 2026-01-25 17:51:55.740111

# %%
df.sort_values('age' , ascending  =  True)
# Out:
#                 Name Department                     Salary  \
# age
# (20.0, 20)   kishori         IT 1970-01-01 00:00:00.005000
# (21.0, 21)      saee         HR 1970-01-01 00:00:10.000000
# (23.0, 23)  Shravani         HR 1970-01-01 00:00:00.000450
# (25.0, 25)   Charlie    Finance 1970-01-01 00:00:00.000300
# (26.0, 26)     David    Medical 1970-01-01 00:00:00.000100
#
#                             Timestamp
# age
# (20.0, 20) 2026-01-25 17:51:55.740111
# (21.0, 21) 2026-01-25 17:51:55.740111
# (23.0, 23) 2026-01-25 17:51:55.740111
# (25.0, 25) 2026-01-25 17:51:55.740111
# (26.0, 26) 2026-01-25 17:51:55.740111

# %%
print(df.columns)
# Out:
# Index(['Name', 'Department', 'Salary', 'Timestamp'], dtype='object')

# %% [markdown]
# ## Shows how much RAM your DataFrame is using, in megabytes (MB).
#
# `deep`=True → counts real memory for text columns
#
# `sum()` → total memory
#
# `/ 1024**2` → converts bytes → MB

# %%
df.memory_usage(deep=True).sum() / 1024**2
# Out:
# np.float64(0.0008974075317382812)
